# %%
#SHOPPING CART
name = input("Enter your name: ")
# Get user's name and price
while True:

  # Validate price input
  while True:
    try:
      price = float(input("Enter the price: "))
      if price <= 0:
        print("Invalid price. ")
      else:
        break
    except:
      print("Invalid price")
      continue

      # Store initial price before any changes
  original_price = price

      # Calculate discount based on initial price
  if original_price > 1000:
      discount = original_price * 0.2  # 20% discount for prices over 1000
  else:
      discount = original_price * 0.1  # 10% discount for prices 1000 or less

      # Check for VIP status and apply additional discount
  vip = input("Are you a VIP? (yes/no): ")
  if vip == "yes":
      discount = discount + (original_price * 0.1)  # Additional 10% discount for VIPs

      # Calculate GST
  gst = original_price * 0.05

      # Adjust price if it's less than 500 (e.g., small order fee)
  if price < 500:
      price = price + 100

      # Give feedback based on the final price
  if price > 10000:
      print("YOU SPEND TOO MUCH")
  elif price < 100:
      print("YOU SPEND SMART")

      # Calculate the final total after all adjustments
  final_total = price - discount + gst

      # Print the receipt details
  print("\n--- RECEIPT ---")
  print("Customer Name: ", name)
  print("Price (adjusted): ", price)
  print("Discount Applied: ", discount)
  print("GST (5%):         ", gst)
  print("Total Amount:     ", final_total)
  print("Thank you for shopping")
  print(f"Have a nice day {name}!")

  over = input("Is your shopping over? (yes/no): ")
  if over == "yes":
      print(f"Goodbye {name}!")
      break
  elif over == "no":
    continue
  else:
    print("Invalid input")
    break
# Out:
# Enter your name: hi
# Enter the price: 78
# Are you a VIP? (yes/no): no
#
# --- RECEIPT ---
# Customer Name:  hi
# Price (adjusted):  178.0
# Discount Applied:  7.800000000000001
# GST (5%):          3.9000000000000004
# Total Amount:      174.1
# Thank you for shopping
# Have a nice day hi!
# Is your shopping over? (yes/no): no
# Enter the price: hi
# Invalid price
# Enter the price: -9
# Invalid price.
# Enter the price: 87
# Are you a VIP? (yes/no): yes
#
# --- RECEIPT ---
# Customer Name:  hi
# Price (adjusted):  187.0
# Discount Applied:  17.400000000000002
# GST (5%):          4.3500000000000005
# Total Amount:      173.95
# Thank you for shopping
# Have a nice day hi!
# Is your shopping over? (yes/no): yes
# Goodbye hi!
